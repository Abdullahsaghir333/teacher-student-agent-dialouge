# %%
# main.py

import os
import time

from dotenv import load_dotenv
load_dotenv()

from rag.loader import load_rag_index
from rag.retriever import RAGRetriever
from agents.student import StudentAgent
from agents.teacher import TeacherAgent
from graph.classroom_graph import build_classroom_graph


if __name__ == "__main__":
    topic = "Quantum Computing"

    print("⚙️ Loading system components...")

    vectorstore = load_rag_index()
    rag = RAGRetriever(vectorstore)

    student = StudentAgent()
    teacher = TeacherAgent()

    graph = build_classroom_graph(student, teacher, rag)

    # Initial State Dictionary
    state = {
        "topic": topic,
        "last_teacher_reply": "I am ready to teach.",
        "last_student_question": "",
        "conversation": []
    }

    print(f"\n🎓 Classroom Session Started: {topic}\n")

    for t in range(3):
        print(f"--- TURN {t+1} ---")

        state = graph.invoke(state)

        role, msg = state["conversation"][-1]
        print(f"{role}: {msg}\n")
        break
        time.sleep(1)


    print("\n===== FULL CONVERSATION =====")
    for role, msg in state["conversation"]:
        print(f"{role}: {msg}\n")
# Out:
# ⚙️ Loading system components...
# c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\rag\loader.py:8: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\langchain_community\embeddings\huggingface.py:84, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      83 try:
# ---> 84     import sentence_transformers
#      86 except ImportError as exc:
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\sentence_transformers\__init__.py:10
#       8 import warnings
# ---> 10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
#      15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\sentence_transformers\backend\__init__.py:5
#       4 from .optimize import export_optimized_onnx_model
# ----> 5 from .quantize import export_dynamic_quantized_onnx_model, export_static_quantized_openvino_model
#       6 from .utils import (
#       7     _save_pretrained_wrapper,
#       8     backend_should_export,
#       9     backend_warn_to_save,
#      10     save_or_push_to_hub_model,
#      11 )
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\sentence_transformers\backend\quantize.py:7
#       6 from sentence_transformers.backend.utils import save_or_push_to_hub_model
# ----> 7 from sentence_transformers.util import disable_datasets_caching, is_datasets_available
#       9 logger = logging.getLogger(__name__)
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\sentence_transformers\util\__init__.py:15
#      14 from .misc import append_to_last_row, disable_datasets_caching, disable_logging, fullname, import_from_string
# ---> 15 from .retrieval import (
#      16     community_detection,
#      17     information_retrieval,
#      18     paraphrase_mining,
#      19     paraphrase_mining_embeddings,
#      20     semantic_search,
#      21 )
#      22 from .similarity import (
#      23     cos_sim,
#      24     dot_score,
#    (...)     32     pytorch_cos_sim,
#      33 )
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\sentence_transformers\util\retrieval.py:13
#      11 from tqdm.autonotebook import tqdm
# ---> 13 from .similarity import cos_sim
#      14 from .tensor import normalize_embeddings
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\sentence_transformers\util\similarity.py:5
#       4 import torch
# ----> 5 from sklearn.metrics import pairwise_distances
#       6 from torch import Tensor
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\sklearn\__init__.py:73
#      69 from . import (  # noqa: F401 E402
#      70     __check_build,
#      71     _distributor_init,
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\sklearn\base.py:19
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      20 from .utils._missing import is_scalar_nan
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\sklearn\utils\__init__.py:9
#       8 from ._bunch import Bunch
# ----> 9 from ._chunking import gen_batches, gen_even_slices
#      11 # Make _safe_indexing importable from here for backward compat as this particular
#      12 # helper is considered semi-private and typically very useful for third-party
#      13 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      14 # _safe_indexing was included in our public API documentation despite the leading
#      15 # `_` in its name.
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\sklearn\utils\_chunking.py:11
#      10 from .._config import get_config
# ---> 11 from ._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\sklearn\utils\_param_validation.py:17
#      16 from .._config import config_context, get_config
# ---> 17 from .validation import _is_arraylike_not_scalar
#      20 class InvalidParameterError(ValueError, TypeError):
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\sklearn\utils\validation.py:21
#      20 from ..exceptions import DataConversionWarning, NotFittedError, PositiveSpectrumWarning
# ---> 21 from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#      22 from ..utils.deprecation import _deprecate_force_all_finite
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\sklearn\utils\_array_api.py:14
#      13 import scipy.sparse as sp
# ---> 14 import scipy.special as special
#      16 from .._config import get_config
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\scipy\special\__init__.py:784
#     782 from ._sf_error import SpecialFunctionWarning, SpecialFunctionError
# --> 784 from . import _ufuncs
#     785 from ._ufuncs import *
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\scipy\special\_ufuncs.pyx:1, in init scipy.special._ufuncs()
#
# ImportError: DLL load failed while importing _ufuncs_cxx: The paging file is too small for this operation to complete.
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 21
#      17 topic = "Quantum Computing"
#      19 print("⚙️ Loading system components...")
# ---> 21 vectorstore = load_rag_index()
#      22 rag = RAGRetriever(vectorstore)
#      24 student = StudentAgent()
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\rag\loader.py:8, in load_rag_index(index_path)
#       7 def load_rag_index(index_path="faiss_index_fast"):
# ----> 8     embeddings = HuggingFaceEmbeddings(
#       9         model_name="sentence-transformers/all-MiniLM-L6-v2"
#      10     )
#      12     vectorstore = FAISS.load_local(
#      13         index_path,
#      14         embeddings,
#      15         allow_dangerous_deserialization=True
#      16     )
#      18     return vectorstore
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\langchain_core\_api\deprecation.py:221, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     219     warned = True
#     220     emit_warning()
# --> 221 return wrapped(self, *args, **kwargs)
#
# File c:\Users\abdul\MYDOCUMENTS\7th semester\genai\Generative_AI_Project\venv\Lib\site-packages\langchain_community\embeddings\huggingface.py:87, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      84     import sentence_transformers
#      86 except ImportError as exc:
# ---> 87     raise ImportError(
#      88         "Could not import sentence_transformers python package. "
#      89         "Please install it with `pip install sentence-transformers`."
#      90     ) from exc
#      92 self.client = sentence_transformers.SentenceTransformer(
#      93     self.model_name, cache_folder=self.cache_folder, **self.model_kwargs
#      94 )
#
# ImportError: Could not import sentence_transformers python package. Please install it with `pip install sentence-transformers`.
